# %% [markdown]
# Make by **was making** in 2008
# 1. Series
# 2. Dataframe
# 3. panel

# %% [markdown]
# Padas in open source Python library for data manipulation and analysis. it was created by Wes Mckinnet in 2008 to effciently work with structured and tabular data. it provides powerfull data structures such as Series and Dataframe, making data cleaning , transformation and analysis easie.

# %% [markdown]
# A Series is a one-dimensional labeled array that is capable of holding data of any type.

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %%
s= pd.Series()
print(s)
# Out:
# Series([], dtype: object)

# %%
s=pd.Series(data=[1,2,3],index=["a","b","c"])

# %%
dic= {"a":100,"b":200,"c":300}
d=pd.Series(data=dic)

# %%
index=["a","b","c","d"]
print(d)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
dic={"a":100,"b":200,"c":300,"d":400}
d=pd.Series(data=dic,index=["a","b","c"])
print(d)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
i = np.array(["a","b","c"])
d = np.arange(1,4)
se=pd.Series(data=d,index=i)
print(se)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s=pd.Series(d=5,index=["a","b","c"])
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1907/3475900598.py in <cell line: 0>()
# ----> 1 s=pd.Series(d=5,index=["a","b","c"])
#       2 print(s)
#
# TypeError: Series.__init__() got an unexpected keyword argument 'd'

# %%
l=[]
d=[]
for i in range(1,5):
  d.append(i)
  l.append(chr(64+i))
s= pd.Series(data=d,index=l)
print(s)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %% [markdown]
# 2. DataFrame

# %% [markdown]
# A DataFrame is a two-dimensional or multi-dimensional data structure. Data is aligned in a tabular format that contains rows and columns.

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data =[1,2,3,4,5]
df=pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data = [["i","ii","iii"],["anvar","Shashi","nisha"],[23,22,21]]
a=data[1][1]
print(a)
c=data[0][1],data[1][1],data[2][1]
print(c)
# c.append(data[0][0])
# c.append(data[1][0])
# c.append(data[2][1])
# print(c)
# Out:
# Shashi
# ('ii', 'Shashi', 22)

# %%
name =["anver","Shashi","krit","shreaya","sushant","nisha"]
py=[45,67,43,23,65,12]
ml=[23,54,34,54,24,25]
d=pd.DataFrame(data=[name,py,ml])
print(d)
# Out:
#        0       1     2        3        4      5
# 0  anver  Shashi  krit  shreaya  sushant  nisha
# 1     45      67    43       23       65     12
# 2     23      54    34       54       24     25

# %%
dic ={"name":name,"py":py,"ml":ml}
d=pd.DataFrame(data=dic)
print(d)
# Out:
#       name  py  ml
# 0    anver  45  23
# 1   Shashi  67  54
# 2     krit  43  34
# 3  shreaya  23  54
# 4  sushant  65  24
# 5    nisha  12  25

# %%
d[d.name=="nisha"]
# Out:
#     name  py  ml
# 5  nisha  12  25

# %%
data ={
    "One":pd.Series([1,2,3],index=["a","b","c"]),
    "Two":pd.Series([1,2,3,4],index=["a","b","c","d"])
}
df=pd.DataFrame(data)
print(df)
# Out:
#    One  Two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
df = pd.DataFrame(np.arange(1,7).reshape(2,3), columns = ["col1","col2","col3"])
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6

# %%
df = pd.read_table("/content/chiporders.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
col = ["sr.no","city","coaching center","course", "state", "course duration"]
df = pd.read_table("/content/course.csv", sep=",", header=None, names=col)
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5       6  Hyderabad           LMN  institute          Could    AP
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# ...

# %%
df_2 = pd.read_table("/content/psd.user", sep="|")
df_2
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
df_2.head(10)
# Out:
#     1  24  M     technician  85711
# 0   2  53  F          other  94043
# 1   3  23  M         writer  32067
# 2   4  24  M     technician  43537
# 3   5  33  F          other  15213
# 4   6  42  M      executive  98101
# 5   7  57  M  administrator  91344
# 6   8  36  M  administrator  05201
# 7   9  29  M        student  01002
# 8  10  53  M         lawyer  90703
# 9  11  39  F          other  30329

# %%
dx = pd.read_excel("/content/exbook.xlsx")
print("head row \n")
dx.head(10)
# Out:
# head row
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
print("tail row \n")
dx.tail(10)
# Out:
# tail row
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
col = ["sr_no","age","gender","jobs","pincode"]
df = pd.read_table("/content/psd.user", sep="|", header=None, names=col)
df
# Out:
#      sr_no  age gender           jobs pincode
# 0        1   24      M     technician   85711
# 1        2   53      F          other   94043
# 2        3   23      M         writer   32067
# 3        4   24      M     technician   43537
# 4        5   33      F          other   15213
# ..     ...  ...    ...            ...     ...
# 938    939   26      F        student   33319
# 939    940   32      M  administrator   02215
# 940    941   20      M        student   97229
# 941    942   48      F      librarian   78209
# 942    943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
df.city.head()
# Out:
# 0       Mumbai
# 1        Delhi
# 2    Bengaluru
# 3       Bhopal
# 4       Mumbai
# Name: city, dtype: object

# %%
df.course.tail()
# Out:
# 20    Data Science
# 21              ML
# 22              DL
# 23           Could
# 24        Web Serv
# Name: course, dtype: object

# %%
df['coaching center'].head(10)
# Out:
# 0         PQR institute .Pvt
# 1     ABC institute .Pvt.LTD
# 2        MNO  institute .Ltd
# 3    RST  institute .Pvt.LTD
# 4    EFG  institute .Pvt.LTD
# 5            LMN  institute
# 6       DEF   institute .Ltd
# 7    PQR  institute .Pvt.LTD
# 8        UVW  institute .Ltd
# 9       GHI   institute .Ltd
# Name: coaching center, dtype: object

# %%
df[['city','course','coaching center', 'state']].head(10)
# Out:
#         city        course          coaching center state
# 0     Mumbai            BI       PQR institute .Pvt    MH
# 1      Delhi            AI   ABC institute .Pvt.LTD    UP
# 2  Bengaluru  Data Science      MNO  institute .Ltd    TN
# 3     Bhopal            ML  RST  institute .Pvt.LTD    MP
# 4     Mumbai            DL  EFG  institute .Pvt.LTD    MH
# 5  Hyderabad         Could          LMN  institute     AP
# 6      Patna      Web Serv     DEF   institute .Ltd    BH
# 7    Channai           AWS  PQR  institute .Pvt.LTD    KT
# 8    Kolkata    Networking      UVW  institute .Ltd    WB
# 9  Hyderabad            AI     GHI   institute .Ltd    AP

# %%
df[['sr.no','coaching center','course']].head(10)
# Out:
#    sr.no          coaching center        course
# 0      1       PQR institute .Pvt            BI
# 1      2   ABC institute .Pvt.LTD            AI
# 2      3      MNO  institute .Ltd  Data Science
# 3      4  RST  institute .Pvt.LTD            ML
# 4      5  EFG  institute .Pvt.LTD            DL
# 5      6          LMN  institute          Could
# 6      7     DEF   institute .Ltd      Web Serv
# 7      8  PQR  institute .Pvt.LTD           AWS
# 8      9      UVW  institute .Ltd    Networking
# 9     10     GHI   institute .Ltd            AI

# %%
df.city +", "+ df['state']
# Out:
# 0        Mumbai, MH
# 1         Delhi, UP
# 2     Bengaluru, TN
# 3        Bhopal, MP
# 4        Mumbai, MH
# 5     Hyderabad, AP
# 6         Patna, BH
# 7       Channai, KT
# 8       Kolkata, WB
# 9     Hyderabad, AP
# 10       Bhopal, MP
# 11         Pune, MH
# 12        Delhi, UP
# 13       Mumbai, MH
# 14        Patna, BH
# 15        Surat, GJ
# 16        Delhi, UP
# 17       Mumbai, MH
# 18         Pune, MH
# 19    Bengaluru, TN
# 20        Surat, Gj
# 21    Hyderabad, AP
# 22       Mumbai, MH
# 23      Channai, KT
# 24        Patna, BH
# dtype: object

# %%
df['loction']=df.city +", "+ df['state']
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5       6  Hyderabad           LMN  institute          Could    AP
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sr.no            25 non-null     int64
#  1   city             25 non-null     object
#  2   coaching center  25 non-null     object
#  3   course           25 non-null     object
#  4   state            25 non-null     object
#  5   course duration  25 non-null     object
#  6   loction          25 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ KB

# %% [markdown]
# #when i create a new columns that it returns datatype ***objects***

# %%
df['coaching deatil']=df['coaching center'] +" | "+ df['state'] +" \ "+df['course duration']
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# 13     14     Mumbai   XYZ  institute .Pvt.LTD         Could    MH
# 14     15      Patna       NOP  institute .Ltd           AWS    BH
# 15     16      Surat       QRS  institute .Ltd            ML    GJ
# 16     17      Delhi           WXY  institute            AWS    UP
# 17     18     Mumbai          ZAB   institute       Web Serv    MH
# ...

# %%
df.drop("coaching deatil",axis=1,inplace=True)
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5       6  Hyderabad           LMN  institute          Could    AP
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# ...

# %%
df.drop(["coaching deatil",'loction'],axis=1,inplace=True)
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 2       3  Bengaluru       MNO  institute .Ltd  Data Science    TN
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5       6  Hyderabad           LMN  institute          Could    AP
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# ...

# %%
df.drop(2,axis=0,inplace=True)
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 3       4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4       5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5       6  Hyderabad           LMN  institute          Could    AP
# 6       7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# 13     14     Mumbai   XYZ  institute .Pvt.LTD         Could    MH
# ...

# %%
df.drop([6,3,4,5],axis=0,inplace=True)
df
# Out:
#     sr.no       city           coaching center        course state  \
# 0       1     Mumbai        PQR institute .Pvt            BI    MH
# 1       2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 7       8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8       9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9      10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10     11     Bhopal          IJK   institute             DL    MP
# 11     12       Pune      KLM   institute .Ltd  Data Science    MH
# 12     13      Delhi       STU  institute .Ltd            BI    UP
# 13     14     Mumbai   XYZ  institute .Pvt.LTD         Could    MH
# 14     15      Patna       NOP  institute .Ltd           AWS    BH
# 15     16      Surat       QRS  institute .Ltd            ML    GJ
# 16     17      Delhi           WXY  institute            AWS    UP
# 17     18     Mumbai          ZAB   institute       Web Serv    MH
# ...

# %% [markdown]
# #Setting a indexing

# %%
col = ["sr.no","city","coaching center","course", "state", "course duration"]
df = pd.read_table("/content/course.csv", sep=",", header=None, names=col)

# %%
df.set_index("course",inplace=True)
df.head()
# Out:
#               sr.no       city           coaching center state course duration
# course
# BI                1     Mumbai        PQR institute .Pvt    MH        9 Months
# AI                2      Delhi    ABC institute .Pvt.LTD    UP       18 Months
# Data Science      3  Bengaluru       MNO  institute .Ltd    TN       11 Months
# ML                4     Bhopal   RST  institute .Pvt.LTD    MP        3 Months
# DL                5     Mumbai   EFG  institute .Pvt.LTD    MH        3 Months
# Could             6  Hyderabad           LMN  institute     AP        4 Months
# Web Serv          7      Patna      DEF   institute .Ltd    BH        4 Months
# AWS               8    Channai   PQR  institute .Pvt.LTD    KT        3 Months
# Networking        9    Kolkata       UVW  institute .Ltd    WB        3 Months
# AI               10  Hyderabad      GHI   institute .Ltd    AP       18 Months
# DL               11     Bhopal          IJK   institute     MP        3 Months
# ...

# %% [markdown]
# #Reseting indexing

# %%
df.index.name='course'
# df.reset_index(inplace=True)
df.head()
# Out:
#               course  sr.no       city          coaching center state  \
# course
# 0                 BI      1     Mumbai       PQR institute .Pvt    MH
# 1                 AI      2      Delhi   ABC institute .Pvt.LTD    UP
# 2       Data Science      3  Bengaluru      MNO  institute .Ltd    TN
# 3                 ML      4     Bhopal  RST  institute .Pvt.LTD    MP
# 4                 DL      5     Mumbai  EFG  institute .Pvt.LTD    MH
#
#        course duration
# course
# 0             9 Months
# 1            18 Months
# 2            11 Months
# 3             3 Months
# 4             3 Months

# %%
class Raj():
  pass
obj=Raj()
type(obj)
# Out:
# __main__.Raj

# %% [markdown]
# #how many methon in pandas

# %%
df.dtypes
# Out:
# course             object
# sr.no               int64
# city               object
# coaching center    object
# state              object
# course duration    object
# dtype: object

# %%
df.shape
# Out:
# (25, 6)

# %%
df.columns
# Out:
# Index(['course', 'sr.no', 'city', 'coaching center', 'state',
#        'course duration'],
#       dtype='object')

# %%
df.size
# Out:
# 150
