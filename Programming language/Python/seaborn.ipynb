# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_table("/content/Automobile_data.csv", sep=",")

# %%
print(df)

# %% [markdown]
# mission value in second column

# %%
df.info()

# %% [markdown]
# that are only three datatype int, floot, object for DS.

# %%
x=np.arange(1,11)
y=np.sqrt(x)

# %%
sns.lineplot(x=x,y=y)
plt.grid(True)

# %%
sns.distplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['width'])
# Out:
# <Axes: xlabel='width', ylabel='Density'>

# %%
mean_width = np.mean(df['width'])
median_width = np.median(df['width'])

# %%
sns.displot(df['width'])
plt.axvline(mean_width,color="red")
plt.axvline(median_width,color="yellow")
plt.grid(True)

# %%
sns.countplot(data=df, x=df['body-style'])
plt.grid(True)

# %%
plt.figure(figsize=(16,9))
# sns.countplot(data=df, x=df['make'])
sns.countplot(df['make'])
# plt.grid(True)
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
# plt.figure(figsize=(16,9))
sns.countplot(df['fuel-type'])
# Out:
# <Axes: xlabel='count', ylabel='fuel-type'>

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.countplot(data=df, x='body-style')
plt.title('Count of Body Styles')
plt.xlabel('Body Style')
plt.ylabel('Count')
plt.grid(True)

plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.countplot(data=df, y='fuel-type')
plt.title('Count of Fuel Types')
plt.xlabel('Count')
plt.ylabel('Fuel Type')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# This cell's content has been merged into the previous cell for a combined plot.
