# %%
import pandas as pd

# %% [markdown]
#   ***Anwar Question***

# %%
# Q1. Read CSV and display last rows
df= pd.read_csv("/content/Dataset - Dataset.csv")
df.tail(10)
# Out:
#      Student_ID          Name  Gender       City Course    Subject  Marks  \
# 990         991   Student_991  Female  Bangalore  BTech   Computer   92.0
# 991         992   Student_992  Female      Delhi    BBA  Economics   47.0
# 992         993   Student_993  Female  Bangalore     BA   Computer    NaN
# 993         994   Student_994  Female     Mumbai    BSc   Computer   92.0
# 994         995   Student_995  Female  Bangalore    BSc    Science    NaN
# 995         996   Student_996    Male       Pune   BCom   Computer   94.0
# 996         997   Student_997    Male    Chennai     BA    Science   92.0
# 997         998   Student_998  Female      Delhi    BSc      Maths   90.0
# 998         999   Student_999  Female    Kolkata  BTech  Economics    NaN
# 999        1000  Student_1000    Male    Chennai     BA   Computer   35.0
#
#      Attendance (%)  Study_Hours  Semester  Target
# 990              60          5.1         1     991
# 991              78          1.4         6     992
# ...

# %%
# Q2. Find Max Marks
df["Marks"].max()
# Out:
# 99.0

# %%
# Q3. Filter student with >60
df["Marks"]>60
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998    False
# 999    False
# Name: Marks, Length: 1000, dtype: bool

# %%
# Q4. Add new column "new target"
df["New target"]=df["Target"]+30
df["New target"]
# Out:
# 0        31
# 1        32
# 2        33
# 3        34
# 4        35
#        ...
# 995    1026
# 996    1027
# 997    1028
# 998    1029
# 999    1030
# Name: New target, Length: 1000, dtype: int64

# %% [markdown]
# ***Krit Question***

# %%
# Q1.Read excel and display last(10)
df=pd.read_excel("/content/Dataset.xlsx")
df.tail(10)
# Out:
#      Student_ID          Name  Gender       City Course    Subject  Marks  \
# 990         991   Student_991  Female  Bangalore  BTech   Computer   92.0
# 991         992   Student_992  Female      Delhi    BBA  Economics   47.0
# 992         993   Student_993  Female  Bangalore     BA   Computer    NaN
# 993         994   Student_994  Female     Mumbai    BSc   Computer   92.0
# 994         995   Student_995  Female  Bangalore    BSc    Science    NaN
# 995         996   Student_996    Male       Pune   BCom   Computer   94.0
# 996         997   Student_997    Male    Chennai     BA    Science   92.0
# 997         998   Student_998  Female      Delhi    BSc      Maths   90.0
# 998         999   Student_999  Female    Kolkata  BTech  Economics    NaN
# 999        1000  Student_1000    Male    Chennai     BA   Computer   35.0
#
#      Attendance (%)  Study_Hours  Semester  Target
# 990              60          5.1         1     991
# 991              78          1.4         6     992
# ...

# %%
# Q2.Find mean of marks
df["Marks"].mean()
# Out:
# np.float64(67.16142270861833)

# %%
# Q3.Create multiple column with subsem.
df[["Subject","Semester"]]
# Out:
#        Subject  Semester
# 0      English         6
# 1      English         3
# 2        Maths         2
# 3     Computer         4
# 4    Economics         2
# ..         ...       ...
# 995   Computer         3
# 996    Science         2
# 997      Maths         5
# 998  Economics         6
# 999   Computer         2
#
# [1000 rows x 2 columns]

# %%
# Q4.Filter the Marks>80
df[df["Marks"] >= 80]
# Out:
#      Student_ID         Name  Gender       City Course    Subject  Marks  \
# 15           16   Student_16    Male      Delhi     BA      Maths   99.0
# 16           17   Student_17  Female  Bangalore   BCom   Computer   83.0
# 20           21   Student_21  Female    Kolkata    BSc    English   94.0
# 24           25   Student_25  Female  Bangalore    BBA  Economics   80.0
# 34           35   Student_35  Female    Kolkata     BA    English   95.0
# ..          ...          ...     ...        ...    ...        ...    ...
# 990         991  Student_991  Female  Bangalore  BTech   Computer   92.0
# 993         994  Student_994  Female     Mumbai    BSc   Computer   92.0
# 995         996  Student_996    Male       Pune   BCom   Computer   94.0
# 996         997  Student_997    Male    Chennai     BA    Science   92.0
# 997         998  Student_998  Female      Delhi    BSc      Maths   90.0
#
#      Attendance (%)  Study_Hours  Semester  Target
# ...

# %% [markdown]
# ***Shivam Question***

# %%
# Q1.What does info method do?
df.info()
# It given the short info of xlsx files
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      1000 non-null   int64
#  1   Name            1000 non-null   object
#  2   Gender          1000 non-null   object
#  3   City            1000 non-null   object
#  4   Course          1000 non-null   object
#  5   Subject         1000 non-null   object
#  6   Marks           731 non-null    float64
#  7   Attendance (%)  1000 non-null   int64
#  8   Study_Hours     1000 non-null   float64
#  9   Semester        1000 non-null   int64
#  10  Target          1000 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %%
# Q2.what is the difference betwen the .loc and .iloc?
df.iloc[0] # it use for access the rows in pandas
df.loc[df["Marks"]<40,"Marks"]=40 # it change the value basic on contaions

# %%
# Q3.What is the difference betwen drop and dropna?
df.dropna(how="all")
df.drop("Study_Hours", axis=1) # it drop
# Out:
#      Student_ID          Name  Gender       City Course    Subject  Marks  \
# 0             1     Student_1    Male    Kolkata    BBA    English    NaN
# 1             2     Student_2  Female     Mumbai  BTech    English    NaN
# 2             3     Student_3    Male     Mumbai    BBA      Maths    NaN
# 3             4     Student_4    Male     Mumbai   BCom   Computer    NaN
# 4             5     Student_5    Male  Bangalore    BSc  Economics    NaN
# ..          ...           ...     ...        ...    ...        ...    ...
# 995         996   Student_996    Male       Pune   BCom   Computer   40.0
# 996         997   Student_997    Male    Chennai     BA    Science   40.0
# 997         998   Student_998  Female      Delhi    BSc      Maths   40.0
# 998         999   Student_999  Female    Kolkata  BTech  Economics    NaN
# 999        1000  Student_1000    Male    Chennai     BA   Computer   40.0
#
#      Attendance (%)  Semester  Target
# 0                10         6       1
# ...

# %%
# Q4.Read CSV and display first 5 rows.
df=pd.read_csv("/content/Dataset - Dataset.csv")
df.head(5)
# Out:
#    Student_ID       Name  Gender       City Course    Subject  Marks  \
# 0           1  Student_1    Male    Kolkata    BBA    English    NaN
# 1           2  Student_2  Female     Mumbai  BTech    English    NaN
# 2           3  Student_3    Male     Mumbai    BBA      Maths    NaN
# 3           4  Student_4    Male     Mumbai   BCom   Computer    NaN
# 4           5  Student_5    Male  Bangalore    BSc  Economics    NaN
#
#    Attendance (%)  Study_Hours  Semester  Target
# 0              77          3.9         6       1
# 1              99          1.3         3       2
# 2              92          5.2         2       3
# 3              71          1.9         4       4
# 4              67          4.6         2       5

# %% [markdown]
# ***Mahi Question***

# %%
# Q1.Access the 4 to 10 row
df.iloc[4:11]
# Out:
#     Student_ID        Name  Gender       City Course    Subject  Marks  \
# 4            5   Student_5    Male  Bangalore    BSc  Economics    NaN
# 5            6   Student_6  Female    Chennai  BTech      Maths    NaN
# 6            7   Student_7    Male  Bangalore   BCom      Maths    NaN
# 7            8   Student_8    Male    Chennai   BCom   Computer    NaN
# 8            9   Student_9    Male  Bangalore  BTech   Computer    NaN
# 9           10  Student_10  Female  Bangalore    BBA    English    NaN
# 10          11  Student_11    Male    Kolkata   BCom   Computer    NaN
#
#     Attendance (%)  Study_Hours  Semester  Target
# 4               67          4.6         2       5
# 5               83          4.9         6       6
# 6               75          4.6         5       7
# 7               63          3.9         1       8
# 8               97          1.1         3       9
# 9               86          2.8         5      10
# ...

# %%
# Q2.Get unigue values on subject column.
df["Subject"].unique()
# Out:
# array(['English', 'Maths', 'Computer', 'Economics', 'Science'],
#       dtype=object)

# %%
# Q3.Add new column and calcuate the total StudyHoues.
df["Total Study Hours"]=df["Study_Hours"]+df["Study_Hours"]
df["Total Study Hours"]
# Out:
# 0       7.8
# 1       2.6
# 2      10.4
# 3       3.8
# 4       9.2
#        ...
# 995     4.6
# 996     6.4
# 997    12.0
# 998     4.2
# 999     3.0
# Name: Total Study Hours, Length: 1000, dtype: float64

# %%
# Q4.Caluclate the makes of each subjects
df.groupby("Subject")["Marks"].sum()
# Out:
# Subject
# Computer     10476.0
# Economics    10233.0
# English      10044.0
# Maths         9881.0
# Science       8461.0
# Name: Marks, dtype: float64

# %% [markdown]
# ***Shreya Question***

# %%
# Q1.Sort column semesterin ascending order
df.sort_values("Semester")
# Out:
#      Student_ID         Name  Gender       City Course    Subject  Marks  \
# 990         991  Student_991  Female  Bangalore  BTech   Computer   92.0
# 984         985  Student_985  Female      Delhi  BTech    English    NaN
# 933         934  Student_934    Male     Mumbai    BSc    Science   47.0
# 943         944  Student_944    Male    Chennai    BSc  Economics   67.0
# 43           44   Student_44  Female     Mumbai   BCom   Computer   37.0
# ..          ...          ...     ...        ...    ...        ...    ...
# 359         360  Student_360    Male      Delhi    BBA      Maths    NaN
# 361         362  Student_362    Male       Pune    BBA    English    NaN
# 5             6    Student_6  Female    Chennai  BTech      Maths    NaN
# 0             1    Student_1    Male    Kolkata    BBA    English    NaN
# 994         995  Student_995  Female  Bangalore    BSc    Science    NaN
#
#      Attendance (%)  Study_Hours  Semester  Target  Total Study Hours
# ...

# %%
# Q2.Find the average Attendance (%)
df["Attendance (%)"].mean()
# Out:
# np.float64(79.383)

# %%
# Q3.Fill the null values in the marks column with median
df.fillna(df["Marks"].median())
# Out:
#      Student_ID          Name  Gender       City Course    Subject  Marks  \
# 0             1     Student_1    Male    Kolkata    BBA    English   69.0
# 1             2     Student_2  Female     Mumbai  BTech    English   69.0
# 2             3     Student_3    Male     Mumbai    BBA      Maths   69.0
# 3             4     Student_4    Male     Mumbai   BCom   Computer   69.0
# 4             5     Student_5    Male  Bangalore    BSc  Economics   69.0
# ..          ...           ...     ...        ...    ...        ...    ...
# 995         996   Student_996    Male       Pune   BCom   Computer   94.0
# 996         997   Student_997    Male    Chennai     BA    Science   92.0
# 997         998   Student_998  Female      Delhi    BSc      Maths   90.0
# 998         999   Student_999  Female    Kolkata  BTech  Economics   69.0
# 999        1000  Student_1000    Male    Chennai     BA   Computer   35.0
#
#      Attendance (%)  Study_Hours  Semester  Target  Total Study Hours
# ...

# %%
#Q4.Drop the column with any null values
df.dropna(axis=1)
# Out:
#      Student_ID          Name  Gender       City Course    Subject  \
# 0             1     Student_1    Male    Kolkata    BBA    English
# 1             2     Student_2  Female     Mumbai  BTech    English
# 2             3     Student_3    Male     Mumbai    BBA      Maths
# 3             4     Student_4    Male     Mumbai   BCom   Computer
# 4             5     Student_5    Male  Bangalore    BSc  Economics
# ..          ...           ...     ...        ...    ...        ...
# 995         996   Student_996    Male       Pune   BCom   Computer
# 996         997   Student_997    Male    Chennai     BA    Science
# 997         998   Student_998  Female      Delhi    BSc      Maths
# 998         999   Student_999  Female    Kolkata  BTech  Economics
# 999        1000  Student_1000    Male    Chennai     BA   Computer
#
#      Attendance (%)  Study_Hours  Semester  Target  Total Study Hours
# 0                77          3.9         6       1                7.8
# ...

# %% [markdown]
# ***Siddhi Question***

# %%
# Q1.Sort Marks in descending and Ascending order.
df.sort_values("Marks")
df.sort_values("Marks",ascending=False)
# Out:
#      Student_ID         Name  Gender       City Course    Subject  Marks  \
# 15           16   Student_16    Male      Delhi     BA      Maths   99.0
# 959         960  Student_960    Male      Delhi   BCom    Science   99.0
# 73           74   Student_74  Female    Chennai    BBA    English   99.0
# 113         114  Student_114  Female    Chennai     BA    Science   99.0
# 104         105  Student_105  Female       Pune     BA  Economics   99.0
# ..          ...          ...     ...        ...    ...        ...    ...
# 980         981  Student_981  Female  Bangalore     BA      Maths    NaN
# 984         985  Student_985  Female      Delhi  BTech    English    NaN
# 992         993  Student_993  Female  Bangalore     BA   Computer    NaN
# 994         995  Student_995  Female  Bangalore    BSc    Science    NaN
# 998         999  Student_999  Female    Kolkata  BTech  Economics    NaN
#
#      Attendance (%)  Study_Hours  Semester  Target
# ...

# %%
# Q2.Add any 2 column and add +10
df["New target"]=df["Target"]+10
df["New target"]
# Out:
# 0        11
# 1        12
# 2        13
# 3        14
# 4        15
#        ...
# 995    1006
# 996    1007
# 997    1008
# 998    1009
# 999    1010
# Name: New target, Length: 1000, dtype: int64

# %%
# Q3.Make any 2 column and group it
df.groupby("Subject")["Marks"].sum()
# Out:
# Subject
# Computer     10476.0
# Economics    10233.0
# English      10044.0
# Maths         9881.0
# Science       8461.0
# Name: Marks, dtype: float64

# %%
# Q4.Marge data is bleow
# Table 1
# id=[4.6,7,10]
# name=[A,D,B,Z]
# Table 2
# id=[7,10,11,12]
# name=[C,D,Y,X]
table1=pd.DataFrame({"id":[4,6,7,10],"Table1_name":["A","D","B","Z"]})
table2=pd.DataFrame({"id":[7,10,11,12],"Table2_name":["C","D","Y","X"]})
pd.merge(table1,table2,on="id")
# Out:
#    id Table1_name Table2_name
# 0   7           B           C
# 1  10           Z           D

# %% [markdown]
# ***Shail Question***

# %%
# Q1.Syntax of import & linking the CSV file and excel files
import pandas as pd
df=pd.read_csv("files-link")

# %%
# Q2.Show All null as values
df.isnull().sum()
# Out:
# Student_ID          0
# Name                0
# Gender              0
# City                0
# Course              0
# Subject             0
# Marks             269
# Attendance (%)      0
# Study_Hours         0
# Semester            0
# Target              0
# New target          0
# dtype: int64

# %%
# Q3.How to modified data and add new column
df.fillna(df["Marks"].mean())
# Out:
#      Student_ID          Name  Gender       City Course    Subject      Marks  \
# 0             1     Student_1    Male    Kolkata    BBA    English  67.161423
# 1             2     Student_2  Female     Mumbai  BTech    English  67.161423
# 2             3     Student_3    Male     Mumbai    BBA      Maths  67.161423
# 3             4     Student_4    Male     Mumbai   BCom   Computer  67.161423
# 4             5     Student_5    Male  Bangalore    BSc  Economics  67.161423
# ..          ...           ...     ...        ...    ...        ...        ...
# 995         996   Student_996    Male       Pune   BCom   Computer  94.000000
# 996         997   Student_997    Male    Chennai     BA    Science  92.000000
# 997         998   Student_998  Female      Delhi    BSc      Maths  90.000000
# 998         999   Student_999  Female    Kolkata  BTech  Economics  67.161423
# 999        1000  Student_1000    Male    Chennai     BA   Computer  35.000000
#
# ...

# %%
# Q4.Make table in Asc and Dec order
df.sort_values("Marks", ascending=False)
df.sort_values("Marks")
# Out:
#      Student_ID         Name  Gender       City Course    Subject  Marks  \
# 15           16   Student_16    Male      Delhi     BA      Maths   99.0
# 959         960  Student_960    Male      Delhi   BCom    Science   99.0
# 73           74   Student_74  Female    Chennai    BBA    English   99.0
# 113         114  Student_114  Female    Chennai     BA    Science   99.0
# 104         105  Student_105  Female       Pune     BA  Economics   99.0
# ..          ...          ...     ...        ...    ...        ...    ...
# 980         981  Student_981  Female  Bangalore     BA      Maths    NaN
# 984         985  Student_985  Female      Delhi  BTech    English    NaN
# 992         993  Student_993  Female  Bangalore     BA   Computer    NaN
# 994         995  Student_995  Female  Bangalore    BSc    Science    NaN
# 998         999  Student_999  Female    Kolkata  BTech  Economics    NaN
#
#      Attendance (%)  Study_Hours  Semester  Target  New target
# ...

# %% [markdown]
# ***Small project***

# %%
import random

def play_game():
    # 1. Define choices
    choices = ['s', 'p', 'r']

    print("--- Stone, Paper, Scissors Game ---")
    print("Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors")

    # 2. Get user input
    user_choice = input("Enter your choice (s/p/r): ").lower()

    if user_choice not in choices:
        print("Invalid choice! Please restart and pick 's', 'p', or 'r'.")
        return

    # 3. Computer's choice
    computer_choice = random.choice(choices)
    print(f"Computer chose: {computer_choice}")

    # 4. Determine result
    if user_choice == computer_choice:
        print("It's a Tie!")

    elif (user_choice == 's' and computer_choice == 'r') or \
         (user_choice == 'p' and computer_choice == 's') or \
         (user_choice == 'r' and computer_choice == 'p'):
        print("You Win!")

    else:
        print("You Lose!")

# Run the game
play_game()
# Out:
# --- Stone, Paper, Scissors Game ---
# Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors
# Enter your choice (s/p/r): P
# Computer chose: p
# It's a Tie!

# %%
import random

def game():
  print("Start of game enter start or exit below")
  start_input=input("Enter your chose ")
  if(start_input=="start"):
    print("Game started")
    while True:
      choices = ['s', 'p', 'r']
      print("\n--- Stone, Paper, Scissors Game ---")
      print("Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors")
      # 2. Get user input
      user_choice = input("Enter your choice (s/p/r): ").lower()

      if user_choice not in choices:
        if user_choice == "start":
          print("Game started")
          continue
        if user_choice == "exit":
          print("Game exit")
          break
      else:
        print("Invalid choice! Please restart and pick 's', 'p', or 'r'.")

      # 3. Computer's choice
      computer_choice = random.choice(choices)
      if (computer_choice == "s"):
        print("Computer chose: Stone")
      elif (computer_choice == "p"):
        print("Computer chose: Paper")
      else:
        print("Computer chose: Scissors")

      # 4. Determine result
      if user_choice == computer_choice:
          print("It's a Tie!")

      elif (user_choice == 's' and computer_choice == 'r') or \
          (user_choice == 'p' and computer_choice == 's') or \
          (user_choice == 'r' and computer_choice == 'p'):
          print("You Win!")

      else:
          print("You Lose!")
  else:
    print("Game exit")
    return

game()
# Out:
# Start of game enter start or exit below
# Enter your chose start
# Game started
#
# --- Stone, Paper, Scissors Game ---
# Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors
# Enter your choice (s/p/r): p
# Invalid choice! Please restart and pick 's', 'p', or 'r'.
# Computer chose: s
# You Win!
#
# --- Stone, Paper, Scissors Game ---
# Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors
# Enter your choice (s/p/r): s
# Invalid choice! Please restart and pick 's', 'p', or 'r'.
# Computer chose: p
# You Lose!
#
# --- Stone, Paper, Scissors Game ---
# Rules: 's' for Stone, 'p' for Paper, 'r' for Scissors
# Enter your choice (s/p/r): exit
# Game exit
